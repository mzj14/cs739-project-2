# %%
import pandas as pd
import numpy as np
import os

# %%
cpu_price = pd.DataFrame(data=[['amazon', 4, 0.17], 
                           ['amazon', 8, 0.34],
                           ['amazon', 16, 0.68],
                           ['amazon', 36, 1.53],
                          ['google', 4, 0.2088],
                          ['google', 8, 0.4176],
                          ['google', 16, 0.8325],
                          ['microsoft', 4, 0.17],
                          ['microsoft', 8, 0.34]],
                    columns=['provider', 'vcpu(s)','price'])

# %%
cpu_price
# Out:
#     provider  vcpu(s)   price
# 0     amazon        4  0.1700
# 1     amazon        8  0.3400
# 2     amazon       16  0.6800
# 3     amazon       36  1.5300
# 4     google        4  0.2088
# 5     google        8  0.4176
# 6     google       16  0.8325
# 7  microsoft        4  0.1700
# 8  microsoft        8  0.3400

# %%
gpu_price = pd.DataFrame(data=[['amazon', 0.9],
                              ['google', 0.481]],
                        columns=['provider','price'])

# %%
OUTPUT_DIR = "outputs/"

# %%
def insert(df, record):
    idx = df.shape[0] + 1
    df.loc[idx] = record

# %%
def summarize_exp(exp):
    exp = exp.rename(columns=exp.iloc[0]).iloc[1:, :]
    for col in exp:
        exp[col] = exp[col].astype('float')
    exp = exp.replace([np.inf, -np.inf], np.nan).dropna(how='any')
    # return peak GFLOPS (throughput)
    return "%.4f"%exp.max()[2]
def process_gpu_benchmark(filename):
    f = open(OUTPUT_DIR + filename)
    provider, device, other = filename.split('_')
    mode, other = other.split('-')
    instance = other.split('.')[0]
    iteration = 0
    start_csv = False
    csv = []
    for line in f:
        if "Experiment ID" in line:
            start_csv = True
        elif "-------------" in line:
            if start_csv:
                start_csv = False
                # finish scanning a csv file
                result = pd.DataFrame(csv)
                record = [summarize_exp(result.iloc[:, i*4+1:i*4+5]) for i in [0, 1, 3]]
                iteration += 1
                insert(gpu, [filename, provider, device, instance, iteration] + record)
                csv = []
        elif start_csv:
            csv.append(line.strip().split(','))

# %%
def process_cpu_benchmark(filename):
    f = open(OUTPUT_DIR + filename)
    provider, vcpu, other = filename.split('_')
    device, other = other.split('-')
    instance = other.split('.')[0]
    iteration = 0
    for line in f:
        if "total time:" in line:
            time = float(line.split(':')[-1].split('s')[0].strip()) * 1000
        elif "total number of events:" in line:
            events = int(line.split(':')[-1].strip())
            time_per_task = time / events
            iteration += 1
            insert(cpu, [filename, provider, vcpu, device, instance, iteration, events, time, time_per_task])

# %%
def process_ml_benchmark(filename):
    f = open(OUTPUT_DIR + filename)
    provider, vcpu, device, other = filename.split('_')
    instance = other.split('-')[-1].split('.')[0]
    iteration = 0
    for line in f:
        if "Accuracy:" in line:
            accuracy = eval(line.strip().split('Accuracy: ')[1].split()[0])
        elif "Total training completion time" in line:
            iteration += 1
            time = line.split()[-2]
            if device == "cpu":
                insert(cpu_ml, [filename, provider, vcpu, device, instance, iteration, accuracy, time])
            else:
                insert(gpu_ml, [filename, provider, vcpu, device, instance, iteration, accuracy, time])

# %%
cpu = pd.DataFrame(columns=['filename', 'provider', 'vcpu(s)', 'device', 'instance', 'iteration', 'events', 'runtime(ms)', 'time_per_task(ms)'])
gpu = pd.DataFrame(columns=['filename', 'provider', 'device', 'instance', 'iteration', 'sp_peak', 'dp_peak', 'im_peak'])
cpu_ml = pd.DataFrame(columns=['filename', 'provider', 'vcpu(s)', 'device', 'instance', 'iteration', 'accuracy', 'runtime(ms)'])
gpu_ml = pd.DataFrame(columns=['filename', 'provider', 'vcpu(s)', 'device', 'instance', 'iteration', 'accuracy', 'runtime(ms)'])
for f in os.listdir(OUTPUT_DIR):
    try:
        if "ml" in f:
            process_ml_benchmark(f)
        elif "cpu" in f:
            process_cpu_benchmark(f)
        elif "gpu" in f:
            process_gpu_benchmark(f)
        else:
            print("Unrecognized Filename: %s"%f)
    except:
        print(f)
        raise
# Out:
# Unrecognized Filename: .DS_Store
# Unrecognized Filename: ocl

# %%
def summarize_cpu(df, target):
    df['vcpu(s)'] = df['vcpu(s)'].astype('int')
    df[target] = df[target].astype('float')
    df = df.merge(cpu_price, how='outer')
    df['normalized_runtime'] = df[target] / float(df.groupby(['provider','vcpu(s)'])[target].mean()[0])
    df['cost_per_task'] = df['normalized_runtime'] * df['price']
    df['normalized_cost'] = df['cost_per_task'] / float(df.groupby(['provider','vcpu(s)'])['cost_per_task'].mean()[0])
    return df

# %%
def summarize_gpu(df, target='runtime(ms)'):
    df = df.merge(gpu_price, how='outer')
    if isinstance(target, list):
        for t in target:
            df[t] = df[t].astype('float')
            df['normalized_%s'%t] = df[t] / df.groupby(['provider'])[t].mean()[0]
            df['cost_per_perf_%s'%t] = df['normalized_%s'%t] * df['price']
            df['normalized_cost_%s'%t] = df['cost_per_perf_%s'%t] / float(df.groupby(['provider'])['cost_per_perf_%s'%t].mean()[0])
            
    else:
        df[target] = df[target].astype('float')
        df['normalized_runtime'] = df[target] / df.groupby(['provider'])[target].mean()[0]
        df['cost_per_task'] = df['normalized_runtime'] * df['price']
        df['normalized_cost'] = df['cost_per_task'] / float(df.groupby(['provider'])['cost_per_task'].mean()[0])
    return df

# %%
summarized_gpu_ml = summarize_gpu(gpu_ml)

# %%
summarized_cpu = summarize_cpu(cpu, 'time_per_task(ms)')

# %%
summarized_cpu_ml = summarize_cpu(cpu_ml, 'runtime(ms)')

# %%
summarized_gpu = summarize_gpu(gpu, ['sp_peak','dp_peak','im_peak'])

# %%
summarized_gpu.head()
# Out:
#                filename provider device instance iteration  sp_peak  dp_peak  \
# 0  amazon_gpu_alt-2.out   amazon    gpu        2         1  3451.88  1375.43
# 1  amazon_gpu_alt-2.out   amazon    gpu        2         2  3449.62  1375.86
# 2  amazon_gpu_alt-2.out   amazon    gpu        2         3  3455.28  1375.69
# 3  amazon_gpu_alt-2.out   amazon    gpu        2         4  3451.55  1375.27
# 4  amazon_gpu_alt-2.out   amazon    gpu        2         5  3469.80  1360.48
#
#    im_peak  price  normalized_sp_peak  cost_per_perf_sp_peak  \
# 0   692.15    0.9            1.007785               0.907006
# 1   690.75    0.9            1.007125               0.906412
# 2   689.31    0.9            1.008777               0.907900
# 3   691.22    0.9            1.007688               0.906920
# 4   691.87    0.9            1.013017               0.911715
#
#    normalized_cost_sp_peak  normalized_dp_peak  cost_per_perf_dp_peak  \
# 0                 1.007785            0.998132               0.898319
# 1                 1.007125            0.998444               0.898599
# 2                 1.008777            0.998321               0.898488
# 3                 1.007688            0.998016               0.898214
# 4                 1.013017            0.987283               0.888555
#
#    normalized_cost_dp_peak  normalized_im_peak  cost_per_perf_im_peak  \
# 0                 0.998132            0.997601               0.897841
# 1                 0.998444            0.995583               0.896025
# 2                 0.998321            0.993507               0.894157
# 3                 0.998016            0.996260               0.896634
# 4                 0.987283            0.997197               0.897477
#
#    normalized_cost_im_peak
# 0                 0.997601
# 1                 0.995583
# 2                 0.993507
# 3                 0.996260
# 4                 0.997197

# %%
summarized_gpu_ml.head()
# Out:
#                 filename provider vcpu(s) device instance iteration  accuracy  \
# 0  amazon_4_gpu_ml-1.out   amazon       4    gpu        1         1    0.9870
# 1  amazon_4_gpu_ml-1.out   amazon       4    gpu        1         2    0.9866
# 2  amazon_4_gpu_ml-1.out   amazon       4    gpu        1         3    0.9864
# 3  amazon_4_gpu_ml-1.out   amazon       4    gpu        1         4    0.9870
# 4  amazon_4_gpu_ml-1.out   amazon       4    gpu        1         5    0.9863
#
#    runtime(ms)  price  normalized_runtime  cost_per_task  normalized_cost
# 0     114515.0    0.9            1.023552       0.921196         1.023552
# 1     113274.0    0.9            1.012459       0.911213         1.012459
# 2     113262.0    0.9            1.012352       0.911117         1.012352
# 3     112760.0    0.9            1.007865       0.907079         1.007865
# 4     113149.0    0.9            1.011342       0.910208         1.011342

# %%
summarized_cpu[summarized_cpu['provider'] == 'google'].sort_values('vcpu(s)')
# Out:
#                 filename provider  vcpu(s) device instance iteration events  \
# 44    google_4_cpu-3.out   google        4    cpu        3         5     13
# 32    google_4_cpu-2.out   google        4    cpu        2         3     12
# 33    google_4_cpu-2.out   google        4    cpu        2         4     15
# 34    google_4_cpu-2.out   google        4    cpu        2         5     16
# 35    google_4_cpu-2.out   google        4    cpu        2         6     16
# 36    google_4_cpu-2.out   google        4    cpu        2         7     15
# 37    google_4_cpu-2.out   google        4    cpu        2         8     14
# 38    google_4_cpu-2.out   google        4    cpu        2         9     15
# 39    google_4_cpu-2.out   google        4    cpu        2        10     16
# 40    google_4_cpu-3.out   google        4    cpu        3         1     16
# 41    google_4_cpu-3.out   google        4    cpu        3         2     16
# 42    google_4_cpu-3.out   google        4    cpu        3         3     13
# 43    google_4_cpu-3.out   google        4    cpu        3         4     15
# 45    google_4_cpu-3.out   google        4    cpu        3         6     14
# 46    google_4_cpu-3.out   google        4    cpu        3         7     15
# 47    google_4_cpu-3.out   google        4    cpu        3         8     18
# 48    google_4_cpu-3.out   google        4    cpu        3         9     44
# 49    google_4_cpu-3.out   google        4    cpu        3        10     14
# 50    google_4_cpu-1.out   google        4    cpu        1         1     22
# 51    google_4_cpu-1.out   google        4    cpu        1         2     43
# 52    google_4_cpu-1.out   google        4    cpu        1         3     20
# 53    google_4_cpu-1.out   google        4    cpu        1         4     12
# 54    google_4_cpu-1.out   google        4    cpu        1         5     15
# 55    google_4_cpu-1.out   google        4    cpu        1         6     15
# 56    google_4_cpu-1.out   google        4    cpu        1         7     15
# 57    google_4_cpu-1.out   google        4    cpu        1         8     14
# 58    google_4_cpu-1.out   google        4    cpu        1         9     16
# 59    google_4_cpu-1.out   google        4    cpu        1        10     16
# 31    google_4_cpu-2.out   google        4    cpu        2         2     15
# 30    google_4_cpu-2.out   google        4    cpu        2         1     16
# ..                   ...      ...      ...    ...      ...       ...    ...
# 156  google_16_cpu-2.out   google       16    cpu        2         7    288
# 160  google_16_cpu-1.out   google       16    cpu        1         1    288
# 157  google_16_cpu-2.out   google       16    cpu        2         8    288
# 158  google_16_cpu-2.out   google       16    cpu        2         9    288
# 159  google_16_cpu-2.out   google       16    cpu        2        10    288
# 161  google_16_cpu-1.out   google       16    cpu        1         2    288
# 167  google_16_cpu-1.out   google       16    cpu        1         8    288
# 163  google_16_cpu-1.out   google       16    cpu        1         4    288
# 164  google_16_cpu-1.out   google       16    cpu        1         5    288
# 165  google_16_cpu-1.out   google       16    cpu        1         6    288
# 166  google_16_cpu-1.out   google       16    cpu        1         7    288
# 155  google_16_cpu-2.out   google       16    cpu        2         6    288
# 162  google_16_cpu-1.out   google       16    cpu        1         3    288
# 154  google_16_cpu-2.out   google       16    cpu        2         5    288
# 140  google_16_cpu-3.out   google       16    cpu        3         1    288
# 152  google_16_cpu-2.out   google       16    cpu        2         3    288
# 151  google_16_cpu-2.out   google       16    cpu        2         2    288
# 150  google_16_cpu-2.out   google       16    cpu        2         1    288
# 149  google_16_cpu-3.out   google       16    cpu        3        10    288
# 148  google_16_cpu-3.out   google       16    cpu        3         9    288
# 147  google_16_cpu-3.out   google       16    cpu        3         8    288
# 146  google_16_cpu-3.out   google       16    cpu        3         7    288
# 145  google_16_cpu-3.out   google       16    cpu        3         6    288
# 144  google_16_cpu-3.out   google       16    cpu        3         5    288
# 143  google_16_cpu-3.out   google       16    cpu        3         4    288
# 142  google_16_cpu-3.out   google       16    cpu        3         3    288
# 141  google_16_cpu-3.out   google       16    cpu        3         2    288
# 168  google_16_cpu-1.out   google       16    cpu        1         9    288
# 153  google_16_cpu-2.out   google       16    cpu        2         4    287
# 169  google_16_cpu-1.out   google       16    cpu        1        10    288
#
#      runtime(ms)  time_per_task(ms)   price  normalized_runtime  \
# 44       12094.5         930.346154  0.2088            5.837705
# 32       11207.5         933.958333  0.2088            5.860371
# 33       13122.7         874.846667  0.2088            5.489459
# 34       12101.1         756.318750  0.2088            4.745724
# 35       12909.5         806.843750  0.2088            5.062756
# 36       12788.2         852.546667  0.2088            5.349531
# 37       12175.9         869.707143  0.2088            5.457209
# 38       12964.4         864.293333  0.2088            5.423239
# 39       12452.7         778.293750  0.2088            4.883612
# 40       12543.5         783.968750  0.2088            4.919221
# 41       11456.1         716.006250  0.2088            4.492772
# 53        1.212465         7.132149
# 54        1.082621         6.368357
# 55        1.125376         6.619859
# 56        1.081511         6.361832
# 57        1.199714         7.057144
# 58        0.993012         5.841244
# 59        0.969142         5.700835
# 31        1.046809         6.157702
# 30        0.991333         5.831370
# ..             ...              ...
# 156       0.187099         1.100582
# 160       0.187191         1.101126
# 157       0.187104         1.100614
# 158       0.187219         1.101286
# 159       0.190349         1.119701
# 161       0.190054         1.117962
# 167       0.190122         1.118368
# 163       0.186956         1.099739
# 164       0.186928         1.099579
# 165       0.186986         1.099920
# 166       0.187712         1.104188
# 155       0.187177         1.101040
# 162       0.187034         1.100198
# 154       0.187159         1.100934
# 140       0.187371         1.102182
# 152       0.187217         1.101275
# 151       0.187086         1.100507
# 150       0.186968         1.099813
# 149       0.187083         1.100486
# 148       0.186977         1.099867
# 147       0.187121         1.100710
# 146       0.187823         1.104839
# 145       0.189366         1.113918
# 144       0.187041         1.100240
# 143       0.187006         1.100038
# 142       0.186928         1.099579
# 141       0.186903         1.099429
# 168       0.187015         1.100091
# 153       0.187825         1.104855
# 169       0.186943         1.099664
#
# [90 rows x 13 columns]

# %%
summarized_cpu[summarized_cpu['provider'] == 'amazon'].sort_values('vcpu(s)')
# Out:
#                 filename provider  vcpu(s) device instance iteration events  \
# 60    amazon_4_cpu-3.out   amazon        4    cpu        3         1     64
# 82    amazon_4_cpu-1.out   amazon        4    cpu        1         3     64
# 83    amazon_4_cpu-1.out   amazon        4    cpu        1         4     64
# 84    amazon_4_cpu-1.out   amazon        4    cpu        1         5     64
# 85    amazon_4_cpu-1.out   amazon        4    cpu        1         6     64
# 86    amazon_4_cpu-1.out   amazon        4    cpu        1         7     64
# 87    amazon_4_cpu-1.out   amazon        4    cpu        1         8     64
# 88    amazon_4_cpu-1.out   amazon        4    cpu        1         9     64
# 89    amazon_4_cpu-1.out   amazon        4    cpu        1        10     64
# 90    amazon_4_cpu-1.out   amazon        4    cpu        1        11     64
# 91    amazon_4_cpu-1.out   amazon        4    cpu        1        12     64
# 92    amazon_4_cpu-1.out   amazon        4    cpu        1        13     64
# 93    amazon_4_cpu-1.out   amazon        4    cpu        1        14     64
# 94    amazon_4_cpu-1.out   amazon        4    cpu        1        15     64
# 95    amazon_4_cpu-1.out   amazon        4    cpu        1        16     64
# 96    amazon_4_cpu-1.out   amazon        4    cpu        1        17     64
# 97    amazon_4_cpu-1.out   amazon        4    cpu        1        18     64
# 98    amazon_4_cpu-1.out   amazon        4    cpu        1        19     64
# 81    amazon_4_cpu-1.out   amazon        4    cpu        1         2     64
# 80    amazon_4_cpu-1.out   amazon        4    cpu        1         1     64
# 99    amazon_4_cpu-1.out   amazon        4    cpu        1        20     64
# 78    amazon_4_cpu-2.out   amazon        4    cpu        2         9     64
# 61    amazon_4_cpu-3.out   amazon        4    cpu        3         2     64
# 62    amazon_4_cpu-3.out   amazon        4    cpu        3         3     64
# 63    amazon_4_cpu-3.out   amazon        4    cpu        3         4     64
# 64    amazon_4_cpu-3.out   amazon        4    cpu        3         5     64
# 65    amazon_4_cpu-3.out   amazon        4    cpu        3         6     64
# 79    amazon_4_cpu-2.out   amazon        4    cpu        2        10     64
# 67    amazon_4_cpu-3.out   amazon        4    cpu        3         8     64
# 68    amazon_4_cpu-3.out   amazon        4    cpu        3         9     64
# ..                   ...      ...      ...    ...      ...       ...    ...
# 209  amazon_36_cpu-1.out   amazon       36    cpu        1        10    576
# 207  amazon_36_cpu-1.out   amazon       36    cpu        1         8    576
# 206  amazon_36_cpu-1.out   amazon       36    cpu        1         7    576
# 205  amazon_36_cpu-1.out   amazon       36    cpu        1         6    576
# 204  amazon_36_cpu-1.out   amazon       36    cpu        1         5    576
# 203  amazon_36_cpu-1.out   amazon       36    cpu        1         4    576
# 202  amazon_36_cpu-1.out   amazon       36    cpu        1         3    576
# 201  amazon_36_cpu-1.out   amazon       36    cpu        1         2    576
# 208  amazon_36_cpu-1.out   amazon       36    cpu        1         9    576
# 238  amazon_36_cpu-3.out   amazon       36    cpu        3         9    576
# 218  amazon_36_cpu-1.out   amazon       36    cpu        1        19    576
# 220  amazon_36_cpu-2.out   amazon       36    cpu        2         1    576
# 236  amazon_36_cpu-3.out   amazon       36    cpu        3         7    576
# 235  amazon_36_cpu-3.out   amazon       36    cpu        3         6    576
# 234  amazon_36_cpu-3.out   amazon       36    cpu        3         5    576
# 233  amazon_36_cpu-3.out   amazon       36    cpu        3         4    576
# 232  amazon_36_cpu-3.out   amazon       36    cpu        3         3    576
# 231  amazon_36_cpu-3.out   amazon       36    cpu        3         2    576
# 230  amazon_36_cpu-3.out   amazon       36    cpu        3         1    576
# 219  amazon_36_cpu-1.out   amazon       36    cpu        1        20    576
# 229  amazon_36_cpu-2.out   amazon       36    cpu        2        10    576
# 227  amazon_36_cpu-2.out   amazon       36    cpu        2         8    576
# 226  amazon_36_cpu-2.out   amazon       36    cpu        2         7    576
# 225  amazon_36_cpu-2.out   amazon       36    cpu        2         6    576
# 224  amazon_36_cpu-2.out   amazon       36    cpu        2         5    576
# 223  amazon_36_cpu-2.out   amazon       36    cpu        2         4    576
# 222  amazon_36_cpu-2.out   amazon       36    cpu        2         3    576
# 221  amazon_36_cpu-2.out   amazon       36    cpu        2         2    576
# 228  amazon_36_cpu-2.out   amazon       36    cpu        2         9    576
# 239  amazon_36_cpu-3.out   amazon       36    cpu        3        10    576
#
#      runtime(ms)  time_per_task(ms)  price  normalized_runtime  cost_per_task  \
# 60       10200.3         159.379688   0.17            1.000070       0.170012
# 82       10193.8         159.278125   0.17            0.999433       0.169904
# 83       10194.0         159.281250   0.17            0.999453       0.169907
# 84       10193.5         159.273438   0.17            0.999404       0.169899
# 85       10197.6         159.337500   0.17            0.999806       0.169967
# 86       10191.9         159.248437   0.17            0.999247       0.169872
# 87       10191.7         159.245313   0.17            0.999227       0.169869
# 88       10195.9         159.310937   0.17            0.999639       0.169939
# 89       10193.3         159.270313   0.17            0.999384       0.169895
# 90       10193.7         159.276562   0.17            0.999423       0.169902
# 89          0.999384
# 90          0.999423
# 91          1.000100
# 92          0.999688
# 93          0.998551
# 94          0.999884
# 95          0.999168
# 96          0.999247
# 97          0.998698
# 98          0.998570
# 81          0.998511
# 80          0.999590
# 99          0.999227
# 78          1.001139
# 61          0.999149
# 62          0.999884
# 63          0.999747
# 64          0.999874
# 65          0.999521
# 79          1.000884
# 67          0.998688
# 68          1.000825
# ..               ...
# 209         1.008669
# 207         1.008247
# 206         1.011130
# 205         1.011110
# 204         1.006551
# 203         1.007012
# 202         1.009502
# 201         1.010600
# 208         1.006463
# 238         1.010316
# 218         1.007228
# 220         1.012904
# 236         1.007982
# 235         1.008894
# 234         1.007277
# 233         1.006580
# 232         1.011600
# 231         1.012316
# 230         1.014032
# 219         1.008188
# 229         1.013041
# 227         1.008924
# 226         1.008120
# 225         1.009002
# 224         1.007541
# 223         1.006914
# 222         1.006698
# 221         1.007198
# 228         1.008061
# 239         1.008610
#
# [160 rows x 13 columns]

# %%
summarized_cpu_ml.head()
# Out:
#                 filename provider  vcpu(s) device instance iteration  \
# 0  amazon_4_cpu_ml-3.out   amazon        4    cpu        3         1
# 1  amazon_4_cpu_ml-3.out   amazon        4    cpu        3         2
# 2  amazon_4_cpu_ml-3.out   amazon        4    cpu        3         3
# 3  amazon_4_cpu_ml-3.out   amazon        4    cpu        3         4
# 4  amazon_4_cpu_ml-3.out   amazon        4    cpu        3         5
#
#    accuracy  runtime(ms)  price  normalized_runtime  cost_per_task  \
# 0    0.9876     240842.0   0.17            0.980479       0.166681
# 1    0.9868     240499.0   0.17            0.979082       0.166444
# 2    0.9852     243172.0   0.17            0.989964       0.168294
# 3    0.9868     245767.0   0.17            1.000528       0.170090
# 4    0.9871     242634.0   0.17            0.987774       0.167922
#
#    normalized_cost
# 0         0.980479
# 1         0.979082
# 2         0.989964
# 3         1.000528
# 4         0.987774

# %%
dfs = []
for col in ['sp_peak', 'dp_peak', 'im_peak']:
    df = summarized_gpu.iloc[:, 0:5]
    df['normalized_peak'] = summarized_gpu['normalized_%s'%col]
    df['normalized_cost'] = summarized_gpu['normalized_cost_%s'%col]
    df['task'] = [col.split('_')[0]] * df.shape[0]
    dfs.append(df)
new_gpu = pd.DataFrame(np.concatenate(dfs), columns = dfs[0].columns)

# %%
new_gpu.head()
# Out:
#                filename provider device instance iteration normalized_peak  \
# 0  amazon_gpu_alt-2.out   amazon    gpu        2         1         1.00778
# 1  amazon_gpu_alt-2.out   amazon    gpu        2         2         1.00712
# 2  amazon_gpu_alt-2.out   amazon    gpu        2         3         1.00878
# 3  amazon_gpu_alt-2.out   amazon    gpu        2         4         1.00769
# 4  amazon_gpu_alt-2.out   amazon    gpu        2         5         1.01302
#
#   normalized_cost task
# 0         1.00778   sp
# 1         1.00712   sp
# 2         1.00878   sp
# 3         1.00769   sp
# 4         1.01302   sp

# %%
for i, df in enumerate([summarized_cpu, new_gpu, summarized_cpu_ml, summarized_gpu_ml]):
    df.to_csv('exp-%d.csv'%i, index=False)
